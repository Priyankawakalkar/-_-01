# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
df=load_iris()
dir(df)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
data=pd.DataFrame(df.data,columns=df.feature_names)

# %%
data['target']=df.target
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
data['flower_names']=data.target.apply(lambda x:df.target_names[x])
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_names
# 0       0       setosa
# 1       0       setosa
# 2       0       setosa
# 3       0       setosa
# 4       0       setosa

# %%
from matplotlib import pyplot as plt
df1=data[data.target==0]
df2=data[data.target==1]
df3=data[data.target==2]

# %%
df1.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_names
# 0       0       setosa
# 1       0       setosa
# 2       0       setosa
# 3       0       setosa
# 4       0       setosa

# %%
df2.head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target flower_names
# 50       1   versicolor
# 51       1   versicolor
# 52       1   versicolor
# 53       1   versicolor
# 54       1   versicolor

# %%
df3.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      target flower_names
# 100       2    virginica
# 101       2    virginica
# 102       2    virginica
# 103       2    virginica
# 104       2    virginica

# %%
# %matplotlib inline

# %%
plt.scatter(df1['sepal length (cm)'],df1['sepal width (cm)'],color='green',marker='+')
# plt.scatter(df2['sepal length (cm)'],df2['sepal width (cm)'],color='red',marker='*')
plt.scatter(df3['sepal length (cm)'],df3['sepal width (cm)'],color='blue',marker='.')

# %%
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_names
# 0       0       setosa
# 1       0       setosa
# 2       0       setosa
# 3       0       setosa
# 4       0       setosa

# %%
feature=data.drop(['target','flower_names'],axis="columns")
target=data.target
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(feature,target,test_size=0.2)

# %%
X_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 127                6.1               3.0                4.9               1.8
# 34                 4.9               3.1                1.5               0.2
# 145                6.7               3.0                5.2               2.3
# 65                 6.7               3.1                4.4               1.4
# 132                6.4               2.8                5.6               2.2
# ..                 ...               ...                ...               ...
# 71                 6.1               2.8                4.0               1.3
# 14                 5.8               4.0                1.2               0.2
# 67                 5.8               2.7                4.1               1.0
# 104                6.5               3.0                5.8               2.2
# 51                 6.4               3.2                4.5               1.5
#
# [120 rows x 4 columns]

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred=model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.9333333333333333
